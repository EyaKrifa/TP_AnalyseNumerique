# %% [markdown]
# # <center style="color:#F10606" > Compte Rendu TP°1  </center>

# %% [markdown]
# # Exercice1

# %% [markdown]
# # 1)

# %%
def p(x):
    return (x-1)**6 # ** puissance
def f(x):
    return x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1

# %%
# le calcul de p(0.998)
print('p({})={} '.format(0.998,p(0.998)))
# le calcul de f(0.998)
print('f({})={} '.format(0.998,f(0.998)))
# Out:
# p(0.998)=6.400000000000034e-17
# f(0.998)=1.7763568394002505e-15

# %%
def horner(p, x):
    if len(p) == 1:
        return p[0]
    p[-2] += x * p[-1]
    return horner(p[:-1], x)

# %%
horner([1, -6, 15, -20, 15, -6, 1], 0.998) # x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1
# Out:
# -1.3322676295501878e-15

# %% [markdown]
# **évaluation de 𝑝(𝑥)  et  𝑓(𝑥)  pour  𝑥  allant de  .998  à  1.002  en choisissant des pas de  .0001**

# %%
import numpy
print('Resultat avec p(x) : Expression réduite')
print('             ')
for i in numpy.arange (0.998, 1.002, 0.001):
    print('p(i)= ', p(i))

print('             ')
print ('Resultat avec f(x) : Expression developpée')
print('             ')
for i in numpy.arange(0.998, 1.002, 0.001):
    print('f(i)= ', f(i))
print('             ')
print ('Resultat avec horner')
print('             ')
for i in numpy.arange(0.998, 1.002, 0.001):
    print('h(i)=' , horner([1, -6, 15, -20, 15, -6, 1], i))
# Out:
# Resultat avec p(x) : Expression réduite
#
# p(i)=  6.400000000000034e-17
# p(i)=  1.0000000000000053e-18
# p(i)=  0.0
# p(i)=  9.999999999993393e-19
# p(i)=  6.400000000000034e-17
#
# Resultat avec f(x) : Expression developpée
#
# f(i)=  1.7763568394002505e-15
# f(i)=  0.0
# f(i)=  0.0
# f(i)=  -2.6645352591003757e-15
# f(i)=  1.7763568394002505e-15
#
# Resultat avec horner
#
# h(i)= -1.3322676295501878e-15
# h(i)= -2.220446049250313e-15
# h(i)= 0.0
# h(i)= -6.661338147750939e-16
# h(i)= -6.661338147750939e-16

# %% [markdown]
# # *2)*

# %%
import matplotlib.pyplot as plt
import numpy as np

'x=np.linspace(0.998, 1.002,100)'
x = np.arange(0.998, 1.002, 0.0001) 
p = lambda x:(x-1)**6 
fig = plt.figure(1, figsize=(9, 7))
plt.plot(x,p(x))

f = lambda x: x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1
plt.plot(x,f(x))
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Solution dans [0.998:0.0001:1.002] ')
plt.grid(True)   
plt.show()

# %% [markdown]
# # Exercice2: Methode de la dichotomie

# %% [markdown]
# **1) La courbe de 𝑓 dans l'intervalle [−2;2]  avec python**

# %%
import matplotlib.pyplot as plt
from numpy import linspace
f=lambda x: x**3+x**2-3*x-3
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))

# %% [markdown]
# **D'aprés le graphe de f il existe 3 solutions**
# - 𝛼1∈]−2;−1.5[
# - 𝛼2∈]−1.5;−0.5[
# -  𝛼3∈]1.5;2[

# %% [markdown]
# **2)un programme dicho.m qui permettra de trouver les solutions de l'équation f(x)=0 avec eps=0.001.**

# %%
def dicho(a,b,f,n):
    for i in range(n):
        c = (a+b)/2
        if f(a)*f(c) <= 0:
            b = c
        else:
            a = c
    return b

# %%
x3=dicho(-2,-1.5,f,10)
x10=dicho(-2,-1.5,f,10)
x20=dicho(-2,-1.5,f,20)
print(x3,x10,x20)
print(x3)
# Out:
# -1.73193359375 -1.73193359375 -1.7320504188537598
# -1.73193359375

# %%
print('f(x10)={},f(x20)={}'.format(f(x10),f(x20)))
# Out:
# f(x10)=0.0002971846843138337,f(x20)=9.857414049463387e-07

# %% [markdown]
# **3)Modification du programme dicho.m pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à $eps$ près**

# %%
def dichow(a,b,f,eps):
    cp=0
    while (b-a)>eps:
        m=(a+b)/2
        if f(m)==0:
            return m
        if f(a)*f(m)<0 : 
            b=m
        else :
            a=m
        cp+=1
    return m,cp

# %%
f=lambda x: x**3+x**2-3*x-3
dichow(-2,-1.5,f,0.0001)
# Out:
# (-1.73199462890625, 13)

# %% [markdown]
# # Exercice3:Methode point fixe

# %% [markdown]
# **1)la courbe de $f$ dans l'intervalle $[1;2]$**

# %%
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+4*x**2-10

t=np.linspace(1,2,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# **2) Vérification que cette équation est équivalente aux 3 schéma du point fixe suivant:**

# %% [markdown]
# **<span style="color:#3339FF">Justification théorique pour la fonction g1**  ,
# On considère l'équation :$$ f(x)=x^3+4x^2-10=0$$
#
# a) $g(x)=\frac{1}{2}\sqrt{10-x^3}=x$.
#
# $$x^3+4x^2-10=0$$
#
# $$4x^2=10-x^3$$
#
# $$2x=\sqrt{10-x^3}$$
#
# $$x=\frac{1}{2}\sqrt{10-x^3}$$
#
# Donc $ f(x)=g(x)$

# %% [markdown]
# **Calcul symbolique de la dérivée**

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g1=lambda x: 1/2*sqrt(10-x**3)

# %%
dg1=lambdify(x,diff(g1(x),x,1))
dg1(1.365)
# Out:
# -0.5117446282927461

# %% [markdown]
# ### Que pouvez vous conclure à propos des convergences de g1???

# %% [markdown]
# **<span style="color:#FF336B "> On conclure que g1 Converge Localement car |g'(x)| < 1**

# %% [markdown]
# **<span style="color:#3339FF">Justification théoriques pour g2**
# On considère l'équation :$$ f(x)=x^3+4x^2-10=0$$
#
# b) $g(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
#
# $$x^3+4x^2-10=0$$$$x^3+4x^2=10$$$$x^2(x+4)=10$$$$x^2=\frac{10}{x+4}$$$$x=\sqrt{\displaystyle\frac{10}{4+x}}$$
# Donc $ f(x)=g(x)$

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g2=lambda x: sqrt(10/(x+4))

# %%
dg2=lambdify(x,diff(g2(x),x,1))
dg2(1.365)
# Out:
# -0.12723758423338585

# %% [markdown]
# ### Que pouvez vous conclure à propos des convergences de g2???

# %% [markdown]
# #### <span style="color:#FF336B "> valeur absolue de la dérivée de g2($\alpha$) < 1 ==> g2 converge </span>

# %% [markdown]
# **<span style="color:#3339FF">Justification théoriques pour g3**
# On considère l'équation :$$ f(x)=x^3+4x^2-10=0$$c) $g(x)=x-x^3-4x^2+10=x$.
#
# $$x^3+4x^2-10=0$$$$x^3+4x^2-10+x-x=0$$$$x^3-4x^2+x-x=10$$$$x^3-4x^2+x=x+10$$$$4x^2+x=x-x^3+10$$$$x=x-x^3-4x^2+10$$
# Donc $ f(x)=g(x)$

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g3=lambda x: x-x**3-4*x**2+10

# %%
dg3=lambdify(x,diff(g3(x),x,1))
dg3(1.365)
# Out:
# -15.509675000000001

# %% [markdown]
# #### <span style="color:#FF336B "> valeur absolue de la dérivée de g3($\alpha$) > 1 ==> g3 diverge </span>

# %% [markdown]
# **<span style="color:#3339FF">Méthode numérique avec python**

# %%
from numpy import sqrt 
f=lambda x:  x**3+4*x**2-10 # la fonction f
g1=lambda x: 1/2*sqrt(10-x**3)
g2=lambda x: sqrt(10/(x+4))
g3=lambda x: x-x**3-4*x**2 + 10

def ptfixe(g,x0,eps,nmax):
    
    zero=x0
    for i in range(nmax):
        x=zero 
        zero=g(x)
        erreur=abs(zero-x)
        if erreur<eps: 
            
            return zero,erreur,i
        
    print('pas de convergence avec le nombre d''iteration')

# %%
ptfixe(g1,1.5,0.001,50)
# Out:
# (1.365410061169957, 0.0005318439762798111, 9)

# %%
ptfixe(g2,1.5,0.001,50)
# Out:
# (1.3652647481134421, 0.0003077327109550776, 3)

# %% [markdown]
# ### quelle est la fonction qui donne la convergence la plus rapide ??
#
# ####  La fonction qui donne la convergence la plus rapide est  $g_2$ </span>
# + $g_2$ donne le resultat en 3 itérations seulement alors que
# + $g_1$ donne le resultat en 9 itérations
# + $g_3$ n'est pas convergente

# %% [markdown]
# ###  <span style="color:#FF336B ">Conclusion: g2 la fonction qui donne la convergence la plus rapide</span>

# %% [markdown]
# # Exercice4:Methode Newton

# %% [markdown]
# # *1)*

# %%
def newton(f,fprime,a,eps):
    x1=a
    x2=x1-(f(x1)/fprime(x1))
    while abs(x1-x2)>eps :
        x1=x2
        x2=x1-(f(x1)/fprime(x1))
        m=x2
    return m

# %% [markdown]
# **On considère la fonction $f(x)=e^{-x}-x$. resultat de l'algorithme `newton.m` à la >fonction $f$, en prenant $x0=0$, $eps=0.001$ **

# %%
import math
from sympy import *
from sympy.abc import x

f=lambda x: math.exp(-x)-x
fprime=lambda x: -math.exp(-x)-1
newton(f,fprime,0,0.001)
# Out:
# 0.5671431650348622

# %% [markdown]
# # 2)

# %%
newton(f,fprime,1,0.001)
# Out:
# 0.567143285989123

# %%
# %load_ext watermark

# %%
# %watermark --iversions
# Out:
# numpy                  1.18.5
# sympy.release          1.6.1
# sympy.multipledispatch 0.4.9

# %%
matplotlib.version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-2421639d99b1> in <module>
# ----> 1 matplotlib.version
#
# NameError: name 'matplotlib' is not defined
